# %%
import kagglehub
from e_commerce_recommendation.configs.settings import BASE_DIR

# Download latest version
path = kagglehub.dataset_download("asaniczka/amazon-india-products-2023-1-5m-products", path=f"{BASE_DIR / "data" / "raw_data"}")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Desktop/datascience/github/e-commerce-recommendation/.venv/lib/python3.13/site-packages/kagglehub/exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File ~/Desktop/datascience/github/e-commerce-recommendation/.venv/lib/python3.13/site-packages/kagglehub/http_resolver.py:131, in DatasetHttpResolver._resolve.<locals>.<lambda>()
#     130 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 131 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
#     132 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# ...

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = f"{BASE_DIR / "data" / "raw_data" / "amazon_india_products_2023.csv"}"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "asaniczka/amazon-india-products-2023-1-5m-products",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_27405/4239861777.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Desktop/datascience/github/e-commerce-recommendation/.venv/lib/python3.13/site-packages/kagglehub/exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File ~/Desktop/datascience/github/e-commerce-recommendation/.venv/lib/python3.13/site-packages/kagglehub/http_resolver.py:131, in DatasetHttpResolver._resolve.<locals>.<lambda>()
#     130 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 131 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
# ...
